# %% [markdown]
# # Agentic Cyber Security Assistant
#
#
# **Capstone Project Level:** Intermediate
#
# ### Learning Outcomes
# By the end of this lab, you will be able to:
#
# - Understand the architecture of an Agentic AI application.
# - Build custom LangChain tools.
# - Integrate a Pinecone-backed RAG tool.
# - Call an external REST API (NVD CVE API).
# - Create multiple agents with `create_agent()`.
# - Orchestrate agents using LangGraph.
# - Share state between agents.
# - Extend the workflow with additional tools and conditional routing.
#
# ---
#
# ## Project Architecture
#
# ```text
#                   User
#                     │
#                     ▼
#              Planner Agent
#                     │
#         ┌───────────┴────────────┐
#         ▼                        ▼
#  Retrieval Agent          Threat Intel Agent
#  (Pinecone RAG)            (NVD CVE API)
#         └───────────┬────────────┘
#                     ▼
#             Validation Agent
#                     │
#                     ▼
#                Final Response
# ```

# %% [markdown]
# ## 1. Environment Setup
#
# Install required libraries and configure API keys.

# %%
pip install -U langchain langgraph langchain-openai langchain-pinecone pinecone requests python-dotenv
# Out:
# Requirement already satisfied: langchain in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (1.3.14)
# Requirement already satisfied: langgraph in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (1.2.9)
# Requirement already satisfied: langchain-openai in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (1.4.1)
# Requirement already satisfied: langchain-pinecone in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (0.2.13)
# Requirement already satisfied: pinecone in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (7.3.0)
# Collecting pinecone
#   Using cached pinecone-9.1.0-cp310-abi3-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: requests in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (2.34.2)
# Requirement already satisfied: python-dotenv in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain) (1.5.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langgraph) (3.8.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.10.9)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (0.25.0)
# Requirement already satisfied: certifi in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.45.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain-openai) (2.46.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (0.14.0)
# Requirement already satisfied: tqdm>4 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (4.69.0)
# Requirement already satisfied: regex in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.1.15)
# Requirement already satisfied: numpy!=2.0.2,>=1.26.4 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain-pinecone) (2.5.1)
# Requirement already satisfied: simsimd>=5.9.11 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from langchain-pinecone) (6.5.16)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from pinecone) (1.8.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.5 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from pinecone) (2.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from requests) (3.4.9)
# Requirement already satisfied: aiohttp>=3.9.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (3.14.2)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.9.1 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.24.5)
# Requirement already satisfied: six>=1.5 in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Requirement already satisfied: colorama in C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.45.0->langchain-openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Imports
#
# Import LangChain, LangGraph, requests and typing.

# %%
import os, requests
from typing import TypedDict
from langchain.tools import tool
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, START, END
# from pinecone import Pinecone
# from langchain_pinecone import PineconeVectorStore

# %% [markdown]
# ## 3. Configuration
#
# Store API keys and project constants.

# %%
from dotenv import load_dotenv
load_dotenv()

OPENAI_API_KEY = os.environ.get('OPENAI_API_KEY')
PINECONE_API_KEY = os.environ.get('PINECONE_API_KEY')
NVD_API_KEY = os.environ.get('NVD_API_KEY')

INDEX_NAME = 'cyber-security'
NAMESPACE = 'cis_documents'

if not OPENAI_API_KEY:
    raise ValueError(
        "OPENAI_API_KEY not found in environment.\n"
        "Create a .env file in this notebook's working directory containing:\n"
        "OPENAI_API_KEY=sk-...\nPINECONE_API_KEY=...\nNVD_API_KEY=..."
    )

llm = ChatOpenAI(model='gpt-4.1-mini', temperature=0)
print("OpenAI key loaded:", OPENAI_API_KEY[:8] + "...")
# Out:
# OpenAI key loaded: sk-proj-...

# %%
# Diagnostic: confirm working directory and .env file location
print("Working directory:", os.getcwd())
print(".env found here:", os.path.exists(".env"))
# Out:
# Working directory: C:\Users\amitk\OneDrive\Agentic-AI\ey-ai-upskill-10-main\32-agentic-capstone-assignments
# .env found here: True

# %% [markdown]
# ## 4. Pinecone
#
# Connect to the existing `cyber-security` index using the `cis_documents` namespace.

# %%
# Placeholder
# pc=Pinecone(api_key=PINECONE_API_KEY)
# index=pc.Index(INDEX_NAME)
# retriever=...
print("Connect your existing Pinecone retriever here.")
# Out:
# Connect your existing Pinecone retriever here.

# %% [markdown]
# ## 5. RAG Tool
#
# Wrap the retriever inside a LangChain tool.

# %%
@tool
def ask_cis(question:str)->str:
    '''Retrieve CIS benchmark guidance from Pinecone.'''
    # docs=retriever.invoke(question)
    return f"[Placeholder RAG] {question}"

# %% [markdown]
# ## 6. CVE Tool
#
# Call the NVD REST API and parse JSON.

# %%
@tool
def lookup_cve(keyword: str) -> str:
    """Search the NVD database for CVEs matching a keyword and return up to 3 results with ID and description."""
    url = 'https://services.nvd.nist.gov/rest/json/cves/2.0'
    params = {'keywordSearch': keyword, 'resultsPerPage': 3}
    headers = {'apiKey': NVD_API_KEY} if NVD_API_KEY else {}
    try:
        r = requests.get(url, params=params, headers=headers, timeout=20)
        r.raise_for_status()
        data = r.json()
        out = []
        for item in data.get('vulnerabilities', []):
            c = item['cve']
            out.append(f"{c['id']} : {c['descriptions'][0]['value'][:150]}")
        return "\n".join(out) if out else "No results"
    except Exception as e:
        return str(e)

# %% [markdown]
# ## 7. Planner Agent
#
# Decides which information is required.

# %%
planner_agent=create_agent(
    model=llm,
    tools=[],
    system_prompt="""You are the Planner Agent.

Return ONLY JSON:
{
  "use_rag": true|false,
  "use_cve": true|false,
  "reason":"..."
}

Rules:
- Configuration, CIS, hardening, benchmark, policy -> use_rag=true
- Latest, CVE, vulnerability, exploit -> use_cve=true
- If both best practices and recent threats are requested -> both true.
"""
)

# %% [markdown]
# ## 8. Retrieval Agent
#
# Uses the RAG tool.

# %%
retrieval_agent=create_agent(
    model=llm,
    tools=[ask_cis],
    system_prompt="You are the Retrieval Agent."
)

# %% [markdown]
# ## 9. Threat Agent
#
# Uses the CVE lookup tool.

# %%
threat_agent=create_agent(
    model=llm,
    tools=[lookup_cve],
    system_prompt="You are the Threat Agent."
)

# %% [markdown]
# ## 10. Validator Agent
#
# Combines evidence into a reliable answer.

# %%
validator_agent=create_agent(
    model=llm,
    tools=[],
    system_prompt="You are the Validator Agent."
)

# %% [markdown]
# ## 11. State
#
# Define the shared graph state.

# %%
class CyberState(TypedDict):
    query: str
    use_rag: bool
    use_cve: bool
    plan: str
    rag: str
    cves: str
    final: str

# %% [markdown]
# ## 12. Graph
#
# Wire agents together using LangGraph.

# %%
import json

def planner_node(state):
    # Production: parse planner JSON. Teaching fallback below.
    q = state["query"].lower()
    use_rag = any(k in q for k in ["cis", "benchmark", "harden", "secure", "configure", "policy", "password", "firewall"])
    use_cve = any(k in q for k in ["cve", "latest", "vulnerab", "exploit", "threat"])
    if "secure" in q and use_cve:
        use_rag = True
    return {"query": state["query"], "use_rag": use_rag, "use_cve": use_cve}

def rag_node(state):
    use_rag = state.get("use_rag", False)
    return {"rag": "" if not use_rag else str(retrieval_agent.invoke({"messages": [{"role": "user", "content": state["query"]}]}))}

def cve_node(state):
    use_cve = state.get("use_cve", False)
    return {"cves": "" if not use_cve else str(threat_agent.invoke({"messages": [{"role": "user", "content": state["query"]}]}))}

def validator_node(state):
    prompt = f'''Query:{state["query"]}

RAG:
{state.get("rag", "")}

CVEs:
{state.get("cves", "")}
'''
    return {"final": str(validator_agent.invoke({"messages": [{"role": "user", "content": prompt}]}))}

def planner_router(state):
    routes = []
    if state["use_rag"]:
        routes.append("rag")
    if state["use_cve"]:
        routes.append("cve")
    if not routes:
        routes = ["rag"]
    return routes

g = StateGraph(CyberState)
g.add_node("planner", planner_node)
g.add_node("rag", rag_node)
g.add_node("cve", cve_node)
g.add_node("validator", validator_node)

g.add_edge(START, "planner")
g.add_conditional_edges("planner", planner_router, {"rag": "rag", "cve": "cve"})
# fan-in: both branches converge
g.add_edge("rag", "validator")
g.add_edge("cve", "validator")
g.add_edge("validator", END)
app = g.compile()

# %% [markdown]
# ## 13. Execution
#
# Invoke the graph on a user query.

# %%
result = app.invoke({'query': 'How do I harden Windows SMB against ransomware?'})
print(result['final'])
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 result = app.invoke({'query': 'How do I harden Windows SMB against ransomware?'})
#       2 print(result['final'])
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langgraph\pregel\main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# -> 3913     for chunk in self.stream(
#    3914         input,
#    3915         config,
#    3916         context=context,
#    3917         stream_mode=(
#    3918             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3919         ),
#    3920         print_mode=print_mode,
#    3921         output_keys=output_keys,
#    3922         interrupt_before=interrupt_before,
#    3923         interrupt_after=interrupt_after,
#    3924         durability=durability,
#    3925         control=control,
#    3926         **kwargs,
#    3927     ):
#    3928         if stream_mode == "values":
#    3929             if len(chunk) == 2:
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langgraph\pregel\main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# Cell In[13], line 14, in rag_node(state)
#      12 def rag_node(state):
#      13     use_rag = state.get("use_rag", False)
# ---> 14     return {"rag": "" if not use_rag else str(retrieval_agent.invoke({"messages": [{"role": "user", "content": state["query"]}]}))}
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langgraph\pregel\main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# -> 3913     for chunk in self.stream(
#    3914         input,
#    3915         config,
#    3916         context=context,
#    3917         stream_mode=(
#    3918             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3919         ),
#    3920         print_mode=print_mode,
#    3921         output_keys=output_keys,
#    3922         interrupt_before=interrupt_before,
#    3923         interrupt_after=interrupt_after,
#    3924         durability=durability,
#    3925         control=control,
#    3926         **kwargs,
#    3927     ):
#    3928         if stream_mode == "values":
#    3929             if len(chunk) == 2:
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langgraph\pregel\main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langchain\agents\factory.py:1447, in create_agent.<locals>.model_node(state, runtime)
#    1435 request = ModelRequest(
#    1436     model=model,
#    1437     tools=default_tools,
#    (...)   1443     runtime=runtime,
#    1444 )
#    1446 if wrap_model_call_handler is None:
# -> 1447     model_response = _execute_model_sync(request)
#    1448     return _build_commands(model_response)
#    1450 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langchain\agents\factory.py:1419, in create_agent.<locals>._execute_model_sync(request)
#    1416 if request.system_message:
#    1417     messages = [request.system_message, *messages]
# -> 1419 output = model_.invoke(messages)
#    1420 if name:
#    1421     output.name = name
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langchain_core\runnables\base.py:6002, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5995 @override
#    5996 def invoke(
#    5997     self,
#    (...)   6000     **kwargs: Any | None,
#    6001 ) -> Output:
# -> 6002     return self.bound.invoke(
#    6003         input,
#    6004         self._merge_configs(config),
#    6005         **{**self.kwargs, **kwargs},
#    6006     )
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langchain_openai\chat_models\base.py:1747, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1745     _handle_openai_bad_request(e)
#    1746 except openai.APIError as e:
# -> 1747     _handle_openai_api_error(e)
#    1748 except Exception as e:
#    1749     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\langchain_openai\chat_models\base.py:1742, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1735         return _construct_lc_result_from_responses_api(
#    1736             response,
#    1737             schema=original_schema_obj,
#    1738             metadata=generation_info,
#    1739             output_version=self.output_version,
#    1740         )
#    1741     else:
# -> 1742         raw_response = self.client.with_raw_response.create(**payload)
#    1743         response = raw_response.parse()
#    1744 except openai.BadRequestError as e:
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1281, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1232 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1233 def create(
#    1234     self,
#    (...)   1278     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1279 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1280     validate_response_format(response_format)
# -> 1281     return self._post(
#    1282         "/chat/completions",
#    1283         body=maybe_transform(
#    1284             {
#    1285                 "messages": messages,
#    1286                 "model": model,
#    1287                 "audio": audio,
#    1288                 "frequency_penalty": frequency_penalty,
#    1289                 "function_call": function_call,
#    1290                 "functions": functions,
#    1291                 "logit_bias": logit_bias,
#    1292                 "logprobs": logprobs,
#    1293                 "max_completion_tokens": max_completion_tokens,
#    1294                 "max_tokens": max_tokens,
#    1295                 "metadata": metadata,
#    1296                 "modalities": modalities,
#    1297                 "moderation": moderation,
#    1298                 "n": n,
#    1299                 "parallel_tool_calls": parallel_tool_calls,
#    1300                 "prediction": prediction,
#    1301                 "presence_penalty": presence_penalty,
#    1302                 "prompt_cache_key": prompt_cache_key,
#    1303                 "prompt_cache_options": prompt_cache_options,
#    1304                 "prompt_cache_retention": prompt_cache_retention,
#    1305                 "reasoning_effort": reasoning_effort,
#    1306                 "response_format": response_format,
#    1307                 "safety_identifier": safety_identifier,
#    1308                 "seed": seed,
#    1309                 "service_tier": service_tier,
#    1310                 "stop": stop,
#    1311                 "store": store,
#    1312                 "stream": stream,
#    1313                 "stream_options": stream_options,
#    1314                 "temperature": temperature,
#    1315                 "tool_choice": tool_choice,
#    1316                 "tools": tools,
#    1317                 "top_logprobs": top_logprobs,
#    1318                 "top_p": top_p,
#    1319                 "user": user,
#    1320                 "verbosity": verbosity,
#    1321                 "web_search_options": web_search_options,
#    1322             },
#    1323             completion_create_params.CompletionCreateParamsStreaming
#    1324             if stream
#    1325             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1326         ),
#    1327         options=make_request_options(
#    1328             extra_headers=extra_headers,
#    1329             extra_query=extra_query,
#    1330             extra_body=extra_body,
#    1331             timeout=timeout,
#    1332             security={"bearer_auth": True},
#    1333         ),
#    1334         cast_to=ChatCompletion,
#    1335         stream=stream or False,
#    1336         stream_cls=Stream[ChatCompletionChunk],
#    1337     )
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\OneDrive\Agentic-AI\ey-ai-upskill-10-main\venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************A2sA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
# During task with name 'model' and id '100d9ef0-c477-fbdf-b27c-60369f405974'
# During task with name 'rag' and id '0146f640-f41f-9f5c-d7e3-f6465c57abc2'

# %% [markdown]
# ## 14. Visualization
#
# Render the LangGraph Mermaid diagram.

# %%
from IPython.display import Image,display
try:
    display(Image(app.get_graph().draw_mermaid_png()))
except Exception as e:
    print(e)

# %% [markdown]
# ## 15. Exercises
#
# Suggested enhancements and assignments.

# %% [markdown]
# ### Suggested Assignments
#
# - see activities\capstone.md

# %% [markdown]
# # Appendix
#
# ## Discussion Questions
#
# - Why do we use tools instead of placing all logic inside one agent?
# - What benefits does LangGraph provide over sequential execution?
# - When should an agent call an external API instead of relying on RAG?
# - How can hallucinations be reduced using validation loops?
#
# ## Best Practices
#
# - Keep tools single-purpose.
# - Keep prompts concise and explicit.
# - Share only necessary state.
# - Validate external data before presenting it.
# - Log agent decisions for debugging and teaching.
